# %% [markdown]
# ## Implementação dos Algoritmos

# %% [markdown]
# ### Geração de números aleatórios

# %%
import random

constant_100     = 10**2
constant_1000    = 10**3
constant_10000   = 10**4
constant_100000  = 10**5
constant_1000000 = 10**6

def generate_random_numbers(quantity):
    random_numbers = []
    for _ in range(quantity):
        random_numbers.append(random.randint(1, constant_1000000))
    return random_numbers

# %% [markdown]
# ## Merge Sort

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = merge_sort(arr[:mid])
    right_half = merge_sort(arr[mid:])

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_index = right_index = 0

    while left_index < len(left) and right_index < len(right):
        if left[left_index] < right[right_index]:
            merged.append(left[left_index])
            left_index += 1
        else:
            merged.append(right[right_index])
            right_index += 1

    merged.extend(left[left_index:])
    merged.extend(right[right_index:])

    return merged

# %% [markdown]
# ### Execução

# %%
values = generate_random_numbers(constant_100)
sorted_values = merge_sort(values)

print("Desordenado:", values)
print("Ordenado:", sorted_values)
# Out:
# Desordenado: [938039, 619587, 740376, 850280, 570733, 506181, 502746, 782964, 412426, 113060, 64789, 456539, 871227, 546922, 946392, 763764, 829313, 68615, 872143, 173101, 667176, 493756, 527, 661026, 970566, 732667, 11285, 29370, 947156, 470952, 697578, 505220, 385551, 585316, 180588, 333956, 282445, 912234, 774475, 21266, 234588, 131580, 976385, 311692, 65255, 987751, 798658, 214109, 48643, 660301, 849887, 754233, 995783, 754838, 185196, 522894, 601393, 430493, 654480, 280292, 404967, 573046, 647905, 353429, 522269, 739366, 924721, 580041, 227564, 684049, 939175, 522055, 832760, 102383, 521291, 25765, 804697, 919323, 387271, 764155, 449744, 107202, 400360, 376347, 456352, 738448, 32610, 247010, 808081, 913737, 683788, 807624, 248869, 266415, 706455, 614405, 192875, 451096, 316644, 125167]
# Ordenado: [527, 11285, 21266, 25765, 29370, 32610, 48643, 64789, 65255, 68615, 102383, 107202, 113060, 125167, 131580, 173101, 180588, 185196, 192875, 214109, 227564, 234588, 247010, 248869, 266415, 280292, 282445, 311692, 316644, 333956, 353429, 376347, 385551, 387271, 400360, 404967, 412426, 430493, 449744, 451096, 456352, 456539, 470952, 493756, 502746, 505220, 506181, 521291, 522055, 522269, 522894, 546922, 570733, 573046, 580041, 585316, 601393, 614405, 619587, 647905, 654480, 660301, 661026, 667176, 683788, 684049, 697578, 706455, 732667, 738448, 739366, 740376, 754233, 754838, 763764, 764155, 774475, 782964, 798658, 804697, 807624, 808081, 829313, 832760, 849887, 850280, 871227, 872143, 912234, 913737, 919323, 924721, 938039, 939175, 946392, 947156, 970566, 976385, 987751, 995783]

# %% [markdown]
# ## Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# %% [markdown]
# ### Execução

# %%
values = generate_random_numbers(constant_100)
sorted_values = quick_sort(values)

print("Desordenado:", values)
print("Ordenado:", sorted_values)
# Out:
# %% [markdown]
# ## Complexidade Assintótica

# %%
import pandas as pd
import time

dados = {
    "Algoritmo": ["Bubble Sort", "Merge Sort", "Quick Sort"],
    "Melhor Caso (Ω)": ["O(n)", "O(n log n)", "O(n log n)"],
    "Caso Médio (Θ)": ["O(n²)", "O(n log n)", "O(n log n)"],
    "Pior Caso (O)": ["O(n²)", "O(n log n)", "O(n²)"]
}

pd.DataFrame(dados)
# Out:
#      Algoritmo Melhor Caso (Ω) Caso Médio (Θ) Pior Caso (O)
# 0  Bubble Sort            O(n)          O(n²)         O(n²)
# 1   Merge Sort      O(n log n)     O(n log n)    O(n log n)
# 2   Quick Sort      O(n log n)     O(n log n)         O(n²)

# %% [markdown]
# ### Melhor Caso

# %% [markdown]
# #### Bubble Sort

# %%
def generate_sorted_numbers(quantity):
    return list(range(1, quantity + 1))

generated_sorted_numbers = generate_sorted_numbers(constant_10000)
generated_random_numbers = generate_random_numbers(constant_10000)

# %%
def bubble_sort_best(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr

inicio_bubble_melhor = time.perf_counter()
bubble_sort_best(generated_sorted_numbers)
fim_bubble_melhor = time.perf_counter()

print(f"Tempo de execução do Bubble Sort (melhor caso): {fim_bubble_melhor - inicio_bubble_melhor:.6f} segundos")
# Out:
# Tempo de execução do Bubble Sort (melhor caso): 0.000472 segundos

# %% [markdown]
# #### Merge Sort

# %%
inicio_merge_melhor = time.perf_counter()
merge_sort(generated_sorted_numbers)
fim_merge_melhor = time.perf_counter()

print(f"Tempo de execução do Merge Sort (melhor caso): {fim_merge_melhor - inicio_merge_melhor:.6f} segundos")
# Out:
# Tempo de execução do Merge Sort (melhor caso): 0.013475 segundos

# %% [markdown]
# #### Quick Sort

# %%
inicio_quick_melhor = time.perf_counter()
quick_sort(generated_sorted_numbers)
fim_quick_melhor = time.perf_counter()

print(f"Tempo de execução do Quick Sort (melhor caso): {fim_quick_melhor - inicio_quick_melhor:.6f} segundos")
# Out:
# Tempo de execução do Quick Sort (melhor caso): 0.010208 segundos

# %% [markdown]
# ### Caso Médio

# %% [markdown]
# #### Bubble Sort

# %%
inicio_bubble_medio = time.perf_counter()
bubble_sort(generated_random_numbers)
fim_bubble_medio = time.perf_counter()

print(f"Tempo de execução do Bubble Sort (caso médio): {fim_bubble_medio - inicio_bubble_medio:.6f} segundos")
# Out:
# Tempo de execução do Bubble Sort (caso médio): 3.550730 segundos

# %% [markdown]
# #### Merge Sort

# %%
inicio_merge_medio = time.perf_counter()
merge_sort(generated_random_numbers)
fim_merge_medio = time.perf_counter()

print(f"Tempo de execução do Merge Sort (caso médio): {fim_merge_medio - inicio_merge_medio:.6f} segundos")
# Out:
# Tempo de execução do Merge Sort (caso médio): 0.017479 segundos

# %% [markdown]
# #### Quick Sort

# %%
inicio_quick_medio = time.perf_counter()
quick_sort(generated_random_numbers)
fim_quick_medio = time.perf_counter()

print(f"Tempo de execução do Quick Sort (caso médio): {fim_quick_medio - inicio_quick_medio:.6f} segundos")
# Out:
# Tempo de execução do Quick Sort (caso médio): 0.015702 segundos

# %% [markdown]
# ### Pior Caso

# %% [markdown]
# #### Bubble Sort

# %%
inicio_bubble_pior = time.perf_counter()
bubble_sort(generated_random_numbers)
fim_bubble_pior = time.perf_counter()

print(f"Tempo de execução do Bubble Sort (pior caso): {fim_bubble_pior - inicio_bubble_pior:.6f} segundos")
# Out:
# Tempo de execução do Bubble Sort (pior caso): 3.551599 segundos

# %% [markdown]
# #### Merge Sort

# %%
inicio_merge_pior = time.perf_counter()
merge_sort(generated_random_numbers)
fim_merge_pior = time.perf_counter()

print(f"Tempo de execução do Merge Sort (pior caso): {fim_merge_pior - inicio_merge_pior:.6f} segundos")
# Out:
# Tempo de execução do Merge Sort (pior caso): 0.016976 segundos

# %% [markdown]
# #### Quick Sort

# %%
def quick_sort_worst(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) - 1] 
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort_worst(left) + middle + quick_sort_worst(right)

inicio_quick_pior = time.perf_counter()
quick_sort_worst(generated_random_numbers)
fim_quick_pior = time.perf_counter()

print(f"Tempo de execução do Quick Sort (pior caso): {fim_quick_pior - inicio_quick_pior:.6f} segundos")
# Out:
# Tempo de execução do Quick Sort (pior caso): 0.015658 segundos

# %% [markdown]
# ## Comparação Entre os Casos

# %%
import matplotlib.pyplot as plt

algoritmos = ["Bubble Sort", "Merge Sort", "Quick Sort"]
melhor_caso = [fim_bubble_melhor - inicio_bubble_melhor, fim_merge_melhor - inicio_merge_melhor, fim_quick_melhor - inicio_quick_melhor]
caso_medio = [fim_bubble_medio - inicio_bubble_medio, fim_merge_medio - inicio_merge_medio, fim_quick_medio - inicio_quick_medio]
pior_caso = [fim_bubble_pior - inicio_bubble_pior, fim_merge_pior - inicio_merge_pior, fim_quick_pior - inicio_quick_pior]
x = range(len(algoritmos))

melhor_caso_merge_quick = [fim_merge_melhor - inicio_merge_melhor, fim_quick_melhor - inicio_quick_melhor]
caso_medio_merge_quick = [fim_merge_medio - inicio_merge_medio, fim_quick_medio - inicio_quick_medio]
pior_caso_merge_quick = [fim_merge_pior - inicio_merge_pior, fim_quick_pior - inicio_quick_pior]
x2 = range(len(algoritmos[1:]))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.bar(x, melhor_caso, width=0.4, label='Melhor Caso', align='center')
ax1.bar(x, caso_medio, width=0.4, label='Caso Médio', align='edge')
ax1.bar(x, pior_caso, width=0.4, label='Pior Caso', align='edge')
ax1.set_xticks(x)
ax1.set_xticklabels(algoritmos)
ax1.set_ylabel('Tempo de Execução (segundos)')
ax1.set_title('Comparação de Tempos de Execução dos Algoritmos de Ordenação')
ax1.legend()

ax2.bar(x2, melhor_caso_merge_quick, width=0.4, label='Melhor Caso', align='center')
ax2.bar(x2, caso_medio_merge_quick, width=0.4, label='Caso Médio', align='edge')
ax2.bar(x2, pior_caso_merge_quick, width=0.4, label='Pior Caso', align='edge')
ax2.set_xticks(x2)
ax2.set_xticklabels(algoritmos[1:])
ax2.set_ylabel('Tempo de Execução (segundos)')
ax2.set_title('Comparação de Tempos de Execução do Merge Sort e Quick Sort')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Consumo de Memória

# %%
import tracemalloc

algoritmos = {
    "Quick Sort": (quick_sort, "O(log n)"),
    "Merge Sort": (merge_sort, "O(n)"),
    "Bubble Sort": (bubble_sort, "O(1)")
}

resultados = []

for nome, (funcao, espaco) in algoritmos.items():
    tracemalloc.start()

    funcao(values)

    memoria_atual, memoria_pico = tracemalloc.get_traced_memory()
    tracemalloc.stop()

    resultados.append([
        nome,
        espaco,
        round(memoria_pico / 1024, 2)
    ])

pd.DataFrame(
    resultados,
    columns=[
        "Algoritmo",
        "Complexidade de Espaço",
        "Pico de Memória (KB)"
    ]
)
# Out:
#      Algoritmo Complexidade de Espaço  Pico de Memória (KB)
# 0   Quick Sort               O(log n)                  5.03
# 1   Merge Sort                   O(n)                  1.77
# 2  Bubble Sort                   O(1)                  0.89

# %% [markdown]
# ## Análise Amortizada

# %% [markdown]
# Neste trabalho, a análise amortizada não se aplica aos algoritmos estudados,pois Bubble Sort, Merge Sort e Quick Sort
# são algoritmos de ordenação e não estruturas de dados dinâmicas.
# Por esse motivo, a comparação foi feita considerando a complexidade assintótica, o consumo de memória e o tempo de execução de cada algoritmo.

# %% [markdown]
# ## Testes e Medição de Desempenho

# %%
import time

algoritmos = {
    "Quick Sort": quick_sort,
    "Merge Sort": merge_sort,
    "Bubble Sort": bubble_sort
}

tamanhos = [constant_100, constant_1000, constant_10000, constant_100000, constant_1000000]

resultados = []

for tamanho in tamanhos:
    values = generate_random_numbers(tamanho)

    for nome, funcao in algoritmos.items():
        if nome == "Bubble Sort" and tamanho > constant_10000:
            continue

        inicio = time.perf_counter()

        funcao(values)

        fim = time.perf_counter()

        resultados.append([
            nome,
            tamanho,
            round((fim - inicio), 4)
        ])

df = pd.DataFrame(
    resultados,
    columns=[
        "Algoritmo",
        "Quantidade de Elementos",
        "Tempo (s)"
    ]
)

tabela = df.pivot(
    index="Algoritmo",
    columns="Quantidade de Elementos",
    values="Tempo (s)"
)

tabela.columns = [f"{col} elementos" for col in tabela.columns]

tabela = tabela.round(4)

tabela
# Out:
#              100 elementos  1000 elementos  10000 elementos  100000 elementos  \
# Algoritmo
# Bubble Sort         0.0003          0.0353           3.5715               NaN
# Merge Sort          0.0001          0.0013           0.0177            0.2050
# Quick Sort          0.0001          0.0012           0.0147            0.1789
#
#              1000000 elementos
# Algoritmo
# Bubble Sort                NaN
# Merge Sort              2.7314
# Quick Sort              2.8852

# %%
import matplotlib.pyplot as plt

tabela.T.plot(marker="o", figsize=(8, 5))

plt.title("Comparação de Desempenho dos Algoritmos")
plt.xlabel("Quantidade de Elementos")
plt.ylabel("Tempo de Execução (s)")
plt.grid(True)

plt.show()

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Com base nas análises realizadas, conclui-se que o Bubble Sort apresentou o pior desempenho para entradas maiores, devido à sua complexidade O(n²). Já o Merge Sort e o Quick Sort obtiveram resultados significativamente melhores, mantendo um crescimento de tempo compatível com O(n log n). Os testes práticos confirmaram a teoria estudada, demonstrando a importância da escolha adequada do algoritmo de ordenação conforme o tamanho da entrada e os recursos disponíveis.
